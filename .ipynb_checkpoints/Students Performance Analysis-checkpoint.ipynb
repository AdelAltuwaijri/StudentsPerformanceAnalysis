# %% [markdown]
# # Student Performans Analysis #
# ### This is the final project required for data science nanodegree by GA & Misk Academy ###
#
# ---

# %% [markdown]
# Dataset available at : https://archive.ics.uci.edu/ml/datasets/student+performance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math as _math

sns.set_style("white")

# %%
#Contents auto-fit
#pd.set_option('display.max_colwidth', 0)
#pd.set_option("display.max_columns",None)
#pd.options.display.max_rows = 4000
pd.option_context('display.precision', 2)

# threshold of sccess variable
pass_score=10

# %% [markdown]
# ## 1. Loading Dataset

# %%
# load data files into data frame objects

math=pd.read_csv("./data/student-mat.csv",delimiter=";")
por=pd.read_csv("./data/student-por.csv",delimiter=";")
math['course']="math"
por['course']="por"
dictionary=pd.read_excel("./data/dictionary.xlsx")
#merging data frams into one data fram
students=pd.concat([math,por],ignore_index = True)

# %% [markdown]
# #### - Data Dictionary :

# %%
dictionary
# Out:
#       Variable               New Name  \
# 0       school                 school
# 1          sex                 gender
# 2          age                    age
# 3      address                address
# 4      famsize            family_size
# 5      Pstatus         parents_status
# 6         Medu       mother_education
# 7         Fedu       father_education
# 8         Mjob             mother_job
# 9         Fjob             father_job
# 10      reason                 reason
# 11    guardian               guardian
# 12  traveltime           commute_time
# 13   studytime             study_time
# 14    failures               failures
# 15   schoolsup         school_support
# 16      famsup         family_support
# 17        paid           paid_classes
# 18     nursery             activities
# 19  activities                nursery
# 20      higher      desire_higher_edu
# 21    internet               internet
# 22    romantic               romantic
# 23      famrel         family_quality
# 24    freetime              free_time
# 25       goout                 go_out
# 26        Dalc  weekday_alcohol_usage
# 27        Walc  weekend_alcohol_usage
# 28      health                 health
# 29    absences               absences
# 30          G1          period1_score
# 31          G2          period2_score
# 32          G3            final_score
# 33      course                 course
#
#                                           Description  \
# 0   student's school (binary: 'GP' - Gabriel Perei...
# 1   student's sex (binary: 'F' - female or 'M' - m...
# 2              student's age (numeric: from 15 to 22)
# 3   student's home address type (binary: 'U' - urb...
# 4   family size (binary: 'LE3' - less or equal to ...
# 5   parent's cohabitation status (binary: 'T' - li...
# 6   mother's education (numeric: 0 - none, 1 - pri...
# 7   father's education (numeric: 0 - none, 1 - pri...
# 8   mother's job (nominal: 'teacher', 'health' car...
# 9   father's job (nominal: 'teacher', 'health' car...
# 10  reason to choose this school (nominal: close t...
# 11  student's guardian (nominal: 'mother', 'father...
# 12  home to school travel time (numeric: 1 - <15 m...
# 13  weekly study time (numeric: 1 - <2 hours, 2 - ...
# 14  number of past class failures (numeric: n if 1...
# 15      extra educational support (binary: yes or no)
# 16     family educational support (binary: yes or no)
# 17  extra paid classes within the course subject (...
# 18        attended nursery school (binary: yes or no)
# 19    extra-curricular activities (binary: yes or no)
# 20  wants to take higher education (binary: yes or...
# 21        Internet access at home (binary: yes or no)
# 22   with a romantic relationship (binary: yes or no)
# 23  quality of family relationships (numeric: from...
# 24  free time after school (numeric: from 1 - very...
# 25  going out with friends (numeric: from 1 - very...
# 26  workday alcohol consumption (numeric: from 1 -...
# 27  weekend alcohol consumption (numeric: from 1 -...
# 28  current health status (numeric: from 1 - very ...
# 29  number of school absences (numeric: from 0 to 93)
# 30         first period grade (numeric: from 0 to 20)
# 31        second period grade (numeric: from 0 to 20)
# 32  final grade (numeric: from 0 to 20, output tar...
# 33                                       course name
#
#                                              Encoding
# 0                                     {"MS":1,"GP":2}
# 1                                       {"M":1,"F":0}
# 2                                                 NaN
# 3                                       {"U":1,"R":0}
# 4                                   {"GT3":1,"LE3":0}
# 5                                       {"T":1,"A":0}
# 6                                                 NaN
# 7                                                 NaN
# 8   {'services':1, 'at_home':2, 'teacher':3, 'heal...
# 9   {'services':1, 'at_home':2, 'teacher':3, 'heal...
# 10  {'course':1, 'home':2, 'reputation':3, 'other':4}
# 11                {'mother':1, 'father':2, 'other':3}
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                   {"yes":1,"no":0}
# 16                                   {"yes":1,"no":0}
# 17                                   {"yes":1,"no":0}
# 18                                   {"yes":1,"no":0}
# 19                                   {"yes":1,"no":0}
# 20                                   {"yes":1,"no":0}
# 21                                   {"yes":1,"no":0}
# 22                                   {"yes":1,"no":0}
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                         {Math,por}

# %% [markdown]
# #### Custom Functions

# %%
# This function takes a column name as a parameter
# and returns a data frame with maximum and minimum value
# of a given column name associeted with a its row values
def min_max_value(col):
    top_index=students[col].idxmax()
    top_value=students["final_score"].max()
    d={top_value : students.loc[top_index] }
    top_obs=pd.DataFrame(data=d)
    
    bottom_index=students[col].idxmin()
    bottom_value=students["final_score"].min()
    d={bottom_value : students.loc[bottom_index]}
    bot_obs=pd.DataFrame(data=d)
    
    min_max_obs=pd.concat([top_obs,bot_obs],axis=1)
    
    return min_max_obs

# %%
# The plotting function below takes takes two arguments, the name of the column and the data associated with that column.
# I would call it repeatedly to plot some of variable distibutions. 
def distribution_plotter(column, data_set,x,y):
    data = data_set[column]
    sns.set(rc={"figure.figsize": (x, y)})
    sns.set(color_codes=True)
    sns.set(style="white", palette="muted")
    dist = sns.distplot(data, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    dist.set_title('Distribution of ' + column + '\n', fontsize=16)

# %%
def get_scores(y_true, y_hat):
    scores = {
        "MSE":   round(metrics.mean_squared_error(y_true, y_hat), 3),
        "MAE":   round(metrics.mean_absolute_error(y_true, y_hat), 3),
        "MedAE": round(metrics.median_absolute_error(y_true, y_hat), 3),
        "RMSE":  round(metrics.mean_squared_error(y_true, y_hat) ** 0.5, 3),
        "R2":    round(metrics.r2_score(y_true, y_hat), 3),
        }
    return scores

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# - Before any analysis step, i would prefer to change column labels to more descriptive names (as shown in dictionary):

# %%
students.columns = ['school','gender','age','address','family_size','parents_status','mother_education','father_education',
           'mother_job','father_job','reason','guardian','commute_time','study_time','failures','school_support',
          'family_support','paid_classes','activities','nursery','desire_higher_edu','internet','romantic','family_quality',
          'free_time','go_out','weekday_alcohol_usage','weekend_alcohol_usage','health','absences','period1_score','period2_score','final_score','course']

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p><b><span style="color:blue">&nbsp; How many rows and columns is there ? </span></b></p>

# %%
print("Rows: {}".format(students.shape[0]), "\nColumns: {}".format(students.shape[1]))
# Out:
# Rows: 1044
# Columns: 34

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; What is the data types of columns? </span></b></p>

# %%
students.dtypes.value_counts()
# Out:
# object    18
# int64     16
# dtype: int64

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; What is the meta data of the dataset? </span></b></p>

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   school                 1044 non-null   object
#  1   gender                 1044 non-null   object
#  2   age                    1044 non-null   int64
#  3   address                1044 non-null   object
#  4   family_size            1044 non-null   object
#  5   parents_status         1044 non-null   object
#  6   mother_education       1044 non-null   int64
#  7   father_education       1044 non-null   int64
#  8   mother_job             1044 non-null   object
#  9   father_job             1044 non-null   object
#  10  reason                 1044 non-null   object
#  11  guardian               1044 non-null   object
#  12  commute_time           1044 non-null   int64
#  13  study_time             1044 non-null   int64
#  14  failures               1044 non-null   int64
#  15  school_support         1044 non-null   object
#  16  family_support         1044 non-null   object
#  17  paid_classes           1044 non-null   object
#  18  activities             1044 non-null   object
#  19  nursery                1044 non-null   object
#  20  desire_higher_edu      1044 non-null   object
#  21  internet               1044 non-null   object
#  22  romantic               1044 non-null   object
#  23  family_quality         1044 non-null   int64
#  24  free_time              1044 non-null   int64
#  25  go_out                 1044 non-null   int64
#  26  weekday_alcohol_usage  1044 non-null   int64
#  27  weekend_alcohol_usage  1044 non-null   int64
#  28  health                 1044 non-null   int64
#  29  absences               1044 non-null   int64
#  30  period1_score          1044 non-null   int64
#  31  period2_score          1044 non-null   int64
#  32  final_score            1044 non-null   int64
#  33  course                 1044 non-null   object
# dtypes: int64(16), object(18)
# memory usage: 204.0+ KB

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Is there any missing values? </span></b></p>

# %%
students.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Is there any row duplications? </span></b></p>

# %%
students.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <b><span style="color:brown">&nbsp; No missing values, No duplications, Great ! </span></b>
#
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; List statistical summary of numerical data ? </span></b></p>

# %%
students.describe().T.style
# Out:
# <style  type="text/css" >
# </style><table id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70elevel0_row0" class="row_heading level0 row0" >age</th>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow0_col0" class="data row0 col0" >1044.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow0_col1" class="data row0 col1" >16.726054</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow0_col2" class="data row0 col2" >1.239975</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow0_col3" class="data row0 col3" >15.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow0_col4" class="data row0 col4" >16.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow0_col5" class="data row0 col5" >17.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow0_col6" class="data row0 col6" >18.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow0_col7" class="data row0 col7" >22.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70elevel0_row1" class="row_heading level0 row1" >mother_education</th>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow1_col0" class="data row1 col0" >1044.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow1_col1" class="data row1 col1" >2.603448</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow1_col2" class="data row1 col2" >1.124907</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow1_col4" class="data row1 col4" >2.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow1_col5" class="data row1 col5" >3.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow1_col6" class="data row1 col6" >4.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow1_col7" class="data row1 col7" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70elevel0_row2" class="row_heading level0 row2" >father_education</th>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow2_col0" class="data row2 col0" >1044.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow2_col1" class="data row2 col1" >2.387931</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow2_col2" class="data row2 col2" >1.099938</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow2_col4" class="data row2 col4" >1.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow2_col5" class="data row2 col5" >2.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow2_col6" class="data row2 col6" >3.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow2_col7" class="data row2 col7" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70elevel0_row3" class="row_heading level0 row3" >commute_time</th>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow3_col0" class="data row3 col0" >1044.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow3_col1" class="data row3 col1" >1.522989</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow3_col2" class="data row3 col2" >0.731727</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow3_col4" class="data row3 col4" >1.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow3_col5" class="data row3 col5" >1.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow3_col6" class="data row3 col6" >2.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow3_col7" class="data row3 col7" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70elevel0_row4" class="row_heading level0 row4" >study_time</th>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow4_col0" class="data row4 col0" >1044.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow4_col1" class="data row4 col1" >1.970307</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow4_col2" class="data row4 col2" >0.834353</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow4_col3" class="data row4 col3" >1.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow4_col5" class="data row4 col5" >2.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow4_col6" class="data row4 col6" >2.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow4_col7" class="data row4 col7" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70elevel0_row5" class="row_heading level0 row5" >failures</th>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow5_col0" class="data row5 col0" >1044.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow5_col1" class="data row5 col1" >0.264368</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow5_col2" class="data row5 col2" >0.656142</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow5_col3" class="data row5 col3" >0.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow5_col4" class="data row5 col4" >0.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow5_col5" class="data row5 col5" >0.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow5_col6" class="data row5 col6" >0.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow5_col7" class="data row5 col7" >3.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70elevel0_row6" class="row_heading level0 row6" >family_quality</th>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow6_col0" class="data row6 col0" >1044.000000</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow6_col1" class="data row6 col1" >3.935824</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow6_col2" class="data row6 col2" >0.933401</td>
#                         <td id="T_b5840e7e_9292_11ea_b3b4_4cbb5888d70erow6_col3" class="data row6 col3" >1.000000</td>
#                         <td i

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; List statistical summary of categorical/textual data ? </span></b></p>

# %%
students.describe(include=['object']).T.style
# Out:
# <style  type="text/css" >
# </style><table id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >unique</th>        <th class="col_heading level0 col2" >top</th>        <th class="col_heading level0 col3" >freq</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row0" class="row_heading level0 row0" >school</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow0_col0" class="data row0 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow0_col1" class="data row0 col1" >2</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow0_col2" class="data row0 col2" >GP</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow0_col3" class="data row0 col3" >772</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row1" class="row_heading level0 row1" >gender</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow1_col0" class="data row1 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow1_col1" class="data row1 col1" >2</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow1_col2" class="data row1 col2" >F</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow1_col3" class="data row1 col3" >591</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row2" class="row_heading level0 row2" >address</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow2_col0" class="data row2 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow2_col1" class="data row2 col1" >2</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow2_col2" class="data row2 col2" >U</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow2_col3" class="data row2 col3" >759</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row3" class="row_heading level0 row3" >family_size</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow3_col0" class="data row3 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow3_col1" class="data row3 col1" >2</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow3_col2" class="data row3 col2" >GT3</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow3_col3" class="data row3 col3" >738</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row4" class="row_heading level0 row4" >parents_status</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow4_col0" class="data row4 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow4_col1" class="data row4 col1" >2</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow4_col2" class="data row4 col2" >T</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow4_col3" class="data row4 col3" >923</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row5" class="row_heading level0 row5" >mother_job</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow5_col0" class="data row5 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow5_col1" class="data row5 col1" >5</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow5_col2" class="data row5 col2" >other</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow5_col3" class="data row5 col3" >399</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row6" class="row_heading level0 row6" >father_job</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow6_col0" class="data row6 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow6_col1" class="data row6 col1" >5</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow6_col2" class="data row6 col2" >other</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow6_col3" class="data row6 col3" >584</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row7" class="row_heading level0 row7" >reason</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow7_col0" class="data row7 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow7_col1" class="data row7 col1" >4</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow7_col2" class="data row7 col2" >course</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow7_col3" class="data row7 col3" >430</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row8" class="row_heading level0 row8" >guardian</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow8_col0" class="data row8 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow8_col1" class="data row8 col1" >3</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow8_col2" class="data row8 col2" >mother</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow8_col3" class="data row8 col3" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row9" class="row_heading level0 row9" >school_support</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow9_col0" class="data row9 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow9_col1" class="data row9 col1" >2</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow9_col2" class="data row9 col2" >no</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow9_col3" class="data row9 col3" >925</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row10" class="row_heading level0 row10" >family_support</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow10_col0" class="data row10 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow10_col1" class="data row10 col1" >2</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow10_col2" class="data row10 col2" >yes</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow10_col3" class="data row10 col3" >640</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row11" class="row_heading level0 row11" >paid_classes</th>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow11_col0" class="data row11 col0" >1044</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow11_col1" class="data row11 col1" >2</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow11_col2" class="data row11 col2" >no</td>
#                         <td id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70erow11_col3" class="data row11 col3" >824</td>
#             </tr>
#             <tr>
#                         <th id="T_b58ffd0c_9292_11ea_8870_4cbb5888d70elevel0_row12" class="row_heading level0 row

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><span style="color:brown">
#
#    - It is noticeable that there are students who scored zero in the final exam!
#    - 50% of students have scored 11 -and lower- of 20.
#    - It seems there are outliers in absences variable. </span>
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; How many students got (Zero) score on final exam ? </span></b></p>

# %%
students[students['final_score'] == 0]["final_score"].count()
# Out:
# 53

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><span style="color:brown">
#
#    - **Potential outliers**
#        - For students who scored zero in the final exam, we do not have definite information as to whether these are real scores or are  parameter values for a reason, such as not taking the final exam.
#        - It is possible that the source data editor imputed missing values with zero for statistical reasons.
#
#
#    - **Addressing the problem**
#    - To address these values, we will suggest two assumptions:
#      1. The zero values recorded in the final exam are the real grades of students who have already taken the exam.
#      2. The zero values recorded in the final exam are numbers that have been imputed for as a result of students not attending the final exam.
#
#
#    - As a result we will handle with all possible scenarios, thuse we create a three data frames:
#      1. **students** : Keeping zero values as they are
#      2. **imputed_students** : Imputing zero values with the mean of non-zero final scores
#      3. **dropped_students** : Dropping zero values.</span>
#
#
# ---

# %% [markdown]
# we will resume EDA process on **students** data frame, and keep the other two frame to use later on in modeling process.

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Statistically, descripe students who take 0 in final exam ? </span></b></p>

# %%
students[students['final_score'] == 0].describe()
# Out:
#              age  mother_education  father_education  commute_time  \
# count  53.000000         53.000000         53.000000     53.000000
# mean   17.283019          2.301887          2.113208      1.660377
# std     1.246184          1.066715          1.068075      0.758120
# min    15.000000          1.000000          1.000000      1.000000
# 25%    16.000000          1.000000          1.000000      1.000000
# 50%    18.000000          2.000000          2.000000      2.000000
# 75%    18.000000          3.000000          3.000000      2.000000
# max    19.000000          4.000000          4.000000      4.000000
#
#        study_time   failures  family_quality  free_time     go_out  \
# count   53.000000  53.000000       53.000000  53.000000  53.000000
# mean     1.830189   0.886792        3.849057   3.245283   3.169811
# std      0.848887   1.012620        1.098885   0.958879   1.410617
# min      1.000000   0.000000        1.000000   1.000000   1.000000
# 25%      1.000000   0.000000        3.000000   3.000000   2.000000
# 50%      2.000000   1.000000        4.000000   3.000000   3.000000
# 75%      2.000000   1.000000        5.000000   4.000000   4.000000
# max      4.000000   3.000000        5.000000   5.000000   5.000000
#
#        weekday_alcohol_usage  weekend_alcohol_usage     health  absences  \
# count              53.000000              53.000000  53.000000      53.0
# mean                1.490566               2.132075   3.660377       0.0
# std                 0.799583               1.256334   1.300050       0.0
# min                 1.000000               1.000000   1.000000       0.0
# 25%                 1.000000               1.000000   3.000000       0.0
# 50%                 1.000000               2.000000   4.000000       0.0
# 75%                 2.000000               3.000000   5.000000       0.0
# max                 4.000000               5.000000   5.000000       0.0
#
#        period1_score  period2_score  final_score
# count      53.000000      53.000000         53.0
# mean        7.396226       4.415094          0.0
# std         1.801064       3.707757          0.0
# min         4.000000       0.000000          0.0
# 25%         6.000000       0.000000          0.0
# 50%         7.000000       5.000000          0.0
# 75%         8.000000       8.000000          0.0
# max        12.000000      10.000000          0.0

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;Who is the top ten percent of students performing in the final exam?? </span></b></p>

# %%
Top_10_perc = students.sort_values(by="final_score",ascending=False).head(int(round((students["age"].count())) * .10))
Top_10_perc
# Out:
#     school gender  age address family_size parents_status  mother_education  \
# 47      GP      M   16       U         GT3              T                 4
# 286     GP      F   18       U         GT3              T                 2
# 374     MS      F   18       R         LE3              T                 4
# 113     GP      M   15       U         LE3              T                 4
# 110     GP      M   15       U         LE3              A                 4
# ..     ...    ...  ...     ...         ...            ...               ...
# 69      GP      F   15       R         LE3              T                 3
# 299     GP      M   18       U         LE3              T                 4
# 596     GP      M   16       U         LE3              T                 2
# 391     MS      M   17       U         LE3              T                 3
# 59      GP      F   16       U         GT3              T                 4
#
#      father_education mother_job father_job  ... free_time go_out  \
# 47                  3     health   services  ...         2      2
# 286                 2    at_home    at_home  ...         3      3
# 374                 4      other      other  ...         4      4
# 113                 2    teacher      other  ...         5      2
# 110                 4    teacher    teacher  ...         5      3
# ..                ...        ...        ...  ...       ...    ...
# 69                  1      other      other  ...         4      2
# 299                 4    teacher    teacher  ...         4      2
# 596                 1      other      other  ...         2      3
# 391                 1   services   services  ...         4      5
# 59                  2   services      other  ...         2      3
#
#      weekday_alcohol_usage  weekend_alcohol_usage  health absences  \
# 47                       1                      1       2        4
# 286                      1                      2       2        5
# 374                      1                      1       1        0
# 113                      1                      1       3       10
# 110                      1                      1       4        6
# ..                     ...                    ...     ...      ...
# 69                       2                      3       3       12
# 299                      2                      2       1        5
# 596                      1                      2       5        0
# 391                      3                      4       2        3
# 59                       1                      1       5        2
#
#     period1_score period2_score final_score course
# 47             19            19          20   math
# 286            18            18          19   math
# 374            19            18          19   math
# 113            18            19          19   math
# 110            18            19          19   math
# ..            ...           ...         ...    ...
# 69             16            16          16   math
# 299            16            15          16   math
# 596            13            14          16    por
# 391            14            16          16   math
# 59             15            16          16   math
#
# [104 rows x 34 columns]

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;What is the main statistical characteristics of top ten percent of students performing in the final exam?</span></b></p>

# %%
Top_10_perc.describe(include="all").T.style
# Out:
# <style  type="text/css" >
# </style><table id="T_b5df095c_9292_11ea_9aec_4cbb5888d70e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >unique</th>        <th class="col_heading level0 col2" >top</th>        <th class="col_heading level0 col3" >freq</th>        <th class="col_heading level0 col4" >mean</th>        <th class="col_heading level0 col5" >std</th>        <th class="col_heading level0 col6" >min</th>        <th class="col_heading level0 col7" >25%</th>        <th class="col_heading level0 col8" >50%</th>        <th class="col_heading level0 col9" >75%</th>        <th class="col_heading level0 col10" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5df095c_9292_11ea_9aec_4cbb5888d70elevel0_row0" class="row_heading level0 row0" >school</th>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col0" class="data row0 col0" >104</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col1" class="data row0 col1" >2</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col2" class="data row0 col2" >GP</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col3" class="data row0 col3" >83</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col4" class="data row0 col4" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col9" class="data row0 col9" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow0_col10" class="data row0 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_b5df095c_9292_11ea_9aec_4cbb5888d70elevel0_row1" class="row_heading level0 row1" >gender</th>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col0" class="data row1 col0" >104</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col1" class="data row1 col1" >2</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col2" class="data row1 col2" >F</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col3" class="data row1 col3" >62</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col4" class="data row1 col4" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col6" class="data row1 col6" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col8" class="data row1 col8" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col9" class="data row1 col9" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow1_col10" class="data row1 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_b5df095c_9292_11ea_9aec_4cbb5888d70elevel0_row2" class="row_heading level0 row2" >age</th>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col0" class="data row2 col0" >104.000000</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col4" class="data row2 col4" >16.634615</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col5" class="data row2 col5" >1.061760</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col6" class="data row2 col6" >15.000000</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col7" class="data row2 col7" >16.000000</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col8" class="data row2 col8" >17.000000</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col9" class="data row2 col9" >17.000000</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow2_col10" class="data row2 col10" >20.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b5df095c_9292_11ea_9aec_4cbb5888d70elevel0_row3" class="row_heading level0 row3" >address</th>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col0" class="data row3 col0" >104</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col1" class="data row3 col1" >2</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col2" class="data row3 col2" >U</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col3" class="data row3 col3" >82</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col4" class="data row3 col4" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col6" class="data row3 col6" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col7" class="data row3 col7" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col8" class="data row3 col8" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col9" class="data row3 col9" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow3_col10" class="data row3 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_b5df095c_9292_11ea_9aec_4cbb5888d70elevel0_row4" class="row_heading level0 row4" >family_size</th>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col0" class="data row4 col0" >104</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col1" class="data row4 col1" >2</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col2" class="data row4 col2" >GT3</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col3" class="data row4 col3" >68</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col4" class="data row4 col4" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col6" class="data row4 col6" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col7" class="data row4 col7" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col8" class="data row4 col8" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col9" class="data row4 col9" >nan</td>
#                         <td id="T_b5df095c_9292_11ea_9aec_4cbb5888d70erow4_col10" class="data row4 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_b5df095c_9292_11ea_9aec_4cbb5888d70elevel0_row5" class="row_

# %% [markdown]
#
#  <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><span style="color:brown">
#
#    - Notes on the top 10 percent of students :
#  - More than 50 percent of students are female
#  - More than 85 percent of students live with their parents
#  - Almost 75 percent of students do not have emotional relationships
#  - All of students wants to take higher education
#  - Almost 99 percent of student did not get extra educational support </span>
#
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;Do males doing better than females in final exam?</span></b></p>

# %%
students.groupby('gender').final_score.mean()
# Out:
# gender
# F    11.448393
# M    11.203091
# Name: final_score, dtype: float64

# %% [markdown]
#  <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><span style="color:brown">
#
#    - Females scored bit hieghr than males In average . </span>
#
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Comparing students performance among two schools ,by gender:</span></b></p>

# %%
 pd.crosstab([students.gender],students.school,values=students["final_score"],aggfunc="mean",margins=True)
# Out:
# school         GP         MS        All
# gender
# F       11.683333  10.871345  11.448393
# M       11.573864   9.910891  11.203091
# All     11.633420  10.514706  11.341954

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><span style="color:brown">
#
#   - From above table we can see that GP students performed better than MS students. </span>
#
# ---

# %%
plt.size=(3,3)
students.hist(column='final_score', by='school',sharex=True, sharey=True);

# %% [markdown]
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;How students ages are distriputed ?</span></b></p>

# %%
distribution_plotter("age", students,5,2)

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; For each age, how many students? and what is the mean and median of there final score ?</span></b></p>

# %%
students.groupby(['age','gender']).final_score.agg(["count","mean","median"])
# Out:
#             count       mean  median
# age gender
# 15  F          95  11.021053    11.0
#     M          99  12.444444    12.0
# 16  F         159  11.779874    12.0
#     M         122  11.450820    11.5
# 17  F         171  12.070175    12.0
#     M         106  10.745283    10.0
# 18  F         127  11.125984    11.0
#     M          95  10.715789    11.0
# 19  F          33   8.939394    10.0
#     M          23   9.000000    10.0
# 20  F           5  12.400000    12.0
#     M           4  13.000000    12.5
# 21  F           1  12.000000    12.0
#     M           2   8.500000     8.5
# 22  M           2   6.500000     6.5

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;Who is the best and lowest performing among students</span></b></p>

# %%
 min_max_value("final_score")
# Out:
#                                20          0
# school                         GP          GP
# gender                          M           M
# age                            16          18
# address                         U           R
# family_size                   GT3         GT3
# parents_status                  T           T
# mother_education                4           2
# father_education                3           2
# mother_job                 health    services
# father_job               services       other
# reason                 reputation  reputation
# guardian                   mother      mother
# commute_time                    1           1
# study_time                      4           1
# failures                        0           2
# school_support                 no          no
# family_support                 no         yes
# paid_classes                   no          no
# activities                    yes         yes
# nursery                       yes         yes
# desire_higher_edu             yes         yes
# internet                      yes         yes
# romantic                       no          no
# family_quality                  4           3
# free_time                       2           3
# go_out                          2           3
# weekday_alcohol_usage           1           1
# weekend_alcohol_usage           1           2
# health                          2           4
# absences                        4           0
# period1_score                  19           7
# period2_score                  19           4
# final_score                    20           0
# course                       math        math

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; How final scores are disriputed ?</span></b></p>

# %%
distribution_plotter("final_score", students,5,2)

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; What is the relationship between period1_score and period2_score ?</span></b></p>

# %%
sns.set(rc={"figure.figsize": (6, 5)})
ax=sns.scatterplot(x="period1_score", y="period2_score",data=students)

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><span style="color:brown">
#
# - There is a positive linear relationship between *period1_score* and *period2_score*. </span>
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Is there a correlation among the columns in the dataframe using ‘Pearson’ method. ? </span></b></p>

# %%
students.corr(method ='pearson')
# Out:
#                             age  mother_education  father_education  \
# age                    1.000000         -0.130196         -0.138521
# mother_education      -0.130196          1.000000          0.642063
# father_education      -0.138521          0.642063          1.000000
# commute_time           0.049216         -0.238181         -0.196328
# study_time            -0.007870          0.090616          0.033458
# failures               0.282364         -0.187769         -0.191390
# family_quality         0.007162          0.015004          0.013066
# free_time              0.002645          0.001054          0.002142
# go_out                 0.118510          0.025614          0.030075
# weekday_alcohol_usage  0.133453          0.001515         -0.000165
# weekend_alcohol_usage  0.098291         -0.029331          0.019524
# health                -0.029129         -0.013254          0.034288
# absences               0.153196          0.059708          0.040829
# period1_score         -0.124121          0.226101          0.195898
# period2_score         -0.119475          0.224662          0.182634
# final_score           -0.125282          0.201472          0.159796
#
#                        commute_time  study_time  failures  family_quality  \
# age                        0.049216   -0.007870  0.282364        0.007162
# mother_education          -0.238181    0.090616 -0.187769        0.015004
# father_education          -0.196328    0.033458 -0.191390        0.013066
# commute_time               1.000000   -0.081328  0.087177       -0.012578
# study_time                -0.081328    1.000000 -0.152024        0.012324
# failures                   0.087177   -0.152024  1.000000       -0.053676
# family_quality            -0.012578    0.012324 -0.053676        1.000000
# free_time                 -0.007403   -0.094429  0.102679        0.136901
# go_out                     0.049740   -0.072941  0.074683        0.080619
# weekday_alcohol_usage      0.109423   -0.159665  0.116336       -0.076483
# weekend_alcohol_usage      0.084292   -0.229073  0.107432       -0.100663
# health                    -0.029002   -0.063044  0.048311        0.104101
# absences                  -0.022669   -0.075594  0.099998       -0.062171
# period1_score             -0.121053    0.211314 -0.374175        0.036947
# period2_score             -0.140163    0.183167 -0.377172        0.042054
# final_score               -0.102627    0.161629 -0.383145        0.054461
#
#                        free_time    go_out  weekday_alcohol_usage  \
# age                     0.002645  0.118510               0.133453
# mother_education        0.001054  0.025614               0.001515
# father_education        0.002142  0.030075              -0.000165
# commute_time           -0.007403  0.049740               0.109423
# study_time             -0.094429 -0.072941              -0.159665
# failures                0.102679  0.074683               0.116336
# family_quality          0.136901  0.080619              -0.076483
# free_time               1.000000  0.323556               0.144979
# go_out                  0.323556  1.000000               0.253135
# weekday_alcohol_usage   0.144979  0.253135               1.000000
# weekend_alcohol_usage   0.130377  0.399794               0.627814
# health                  0.081517 -0.013736               0.065515
# absences               -0.032079  0.056142               0.132867
# period1_score          -0.051985 -0.101163              -0.150943
# period2_score          -0.068952 -0.108411              -0.131576
# final_score            -0.064890 -0.097877              -0.129642
#
#                        weekend_alcohol_usage    health  absences  \
# age                                 0.098291 -0.029129  0.153196
# mother_education                   -0.029331 -0.013254  0.059708
# father_education                    0.019524  0.034288  0.040829
# commute_time                        0.084292 -0.029002 -0.022669
# study_time                         -0.229073 -0.063044 -0.075594
# failures                            0.107432  0.048311  0.099998
# family_quality                     -0.100663  0.104101 -0.062171
# free_time                           0.130377  0.081517 -0.032079
# go_out                              0.399794 -0.013736  0.056142
# weekday_alcohol_usage               0.627814  0.065515  0.132867
# weekend_alcohol_usage               1.000000  0.106669  0.139703
# health                              0.106669  1.000000 -0.027479
# absences                            0.139703 -0.027479  1.000000
# period1_score                      -0.142401 -0.060478 -0.092425
# period2_score                      -0.128114 -0.088001 -0.089332
# final_score                        -0.115740 -0.080079 -0.045671
#
#                        period1_score  period2_score  final_score
# age                        -0.124121      -0.119475    -0.125282
# mother_education            0.226101       0.224662     0.201472
# father_education            0.195898       0.182634     0.159796
# commute_time               -0.121053      -0.140163    -0.102627
# study_time                  0.211314       0.183167     0.161629
# failures                   -0.374175      -0.377172    -0.383145
# family_quality              0.036947       0.042054     0.054461
# free_time                  -0.051985      -0.068952    -0.064890
# go_out                     -0.101163      -0.108411    -0.097877
# weekday_alcohol_usage      -0.150943      -0.131576    -0.129642
# weekend_alcohol_usage      -0.142401      -0.128114    -0.115740
# health                     -0.060478      -0.088001    -0.080079
# absences                   -0.092425      -0.089332    -0.045671
# period1_score               1.000000       0.858739     0.809142
# period2_score               0.858739       1.000000     0.910743
# final_score                 0.809142       0.910743     1.000000

# %% [markdown]
# ## Visualizing correlations:

# %%
sns.set_palette("coolwarm", 7)
sns.set(rc={"figure.figsize": (16, 8)})
sns.heatmap(students.corr(method ='pearson'), annot=True, linewidth=0.4, vmin=-1, vmax=1)
plt.yticks(rotation=0);

# %% [markdown]
# ## 2.Features Engineering

# %% [markdown]
# ### - How independant variables are correlated with each other ?

# %%
plt.figure(figsize=(27,12))
sns.heatmap(students.corr(),annot=True,cmap='YlGnBu')

# %% [markdown]
# ### Discussing independant variables correlations:

# %% [markdown]
# - It is noticeable by looking at correlation matrix above that there are some independant variables linked to each other by more than %50 , keeping them together in the model might decrease the model performance and effect its ability to  predict correctly.
#
# - This issue of correlation called **collinearity**

# %% [markdown]
# #### The correlations have been located in a dataset:
# - **Correlation 1 :** period1_score <--> period2_score
# - **Correlation 2 :** mother_education <--> father_education
# - **Correlation 3 :** weekday_alcohol_usage <--> weekend_alcohol_usage

# %% [markdown]
# -  To solve correlation isuue I will delete one variable from each pair of correlated variables, the lower correlated variabled with a target is a good candidate to delete.
#
#
# - Let's take a clear look at the correlations of independant variables with the target variable:

# %%
df=students[["mother_education", "father_education","weekday_alcohol_usage","weekend_alcohol_usage", \
          "period1_score","period2_score","final_score"]].corr()
df=df.loc[:,["final_score"]]
df.style.bar(subset=['final_score'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 11.5%, #5fba7d 11.5%, #5fba7d 29.3%, transparent 29.3%);
#         }    #T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 11.5%, #5fba7d 11.5%, #5fba7d 25.6%, transparent 25.6%);
#         }    #T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.5%, transparent 11.5%);
#         }    #T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 1.2%, #d65f5f 1.2%, #d65f5f 11.5%, transparent 11.5%);
#         }    #T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 11.5%, #5fba7d 11.5%, #5fba7d 83.1%, transparent 83.1%);
#         }    #T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 11.5%, #5fba7d 11.5%, #5fba7d 92.1%, transparent 92.1%);
#         }    #T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 11.5%, #5fba7d 11.5%, #5fba7d 100.0%, transparent 100.0%);
#         }</style><table id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >final_score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70elevel0_row0" class="row_heading level0 row0" >mother_education</th>
#                         <td id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow0_col0" class="data row0 col0" >0.201472</td>
#             </tr>
#             <tr>
#                         <th id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70elevel0_row1" class="row_heading level0 row1" >father_education</th>
#                         <td id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow1_col0" class="data row1 col0" >0.159796</td>
#             </tr>
#             <tr>
#                         <th id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70elevel0_row2" class="row_heading level0 row2" >weekday_alcohol_usage</th>
#                         <td id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow2_col0" class="data row2 col0" >-0.129642</td>
#             </tr>
#             <tr>
#                         <th id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70elevel0_row3" class="row_heading level0 row3" >weekend_alcohol_usage</th>
#                         <td id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow3_col0" class="data row3 col0" >-0.115740</td>
#             </tr>
#             <tr>
#                         <th id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70elevel0_row4" class="row_heading level0 row4" >period1_score</th>
#                         <td id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow4_col0" class="data row4 col0" >0.809142</td>
#             </tr>
#             <tr>
#                         <th id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70elevel0_row5" class="row_heading level0 row5" >period2_score</th>
#                         <td id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow5_col0" class="data row5 col0" >0.910743</td>
#             </tr>
#             <tr>
#                         <th id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70elevel0_row6" class="row_heading level0 row6" >final_score</th>
#                         <td id="T_b8dc01ae_9292_11ea_a380_4cbb5888d70erow6_col0" class="data row6 col0" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# [Styling — pandas 1.0.3 documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html)

# %% [markdown]
# - According to values of correlations for each pair of variable with a target variable, Below is a list of what variables will be deleted and preserved:
#     - mother_education
#     - ~father_education~
#
#     - weekday_alcohol_usage
#     - ~weekend_alcohol_usage~
#
#     - ~period1_score~
#     - period2_score

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# - For modeling process, all categorical values must be converted to numerical, because scikit-learn expects all features to be  numeric

# %% [markdown]
# - For **Ordered categories** i will left them as they are, because they have already encoded with sensible numeric values
# - For **Unordered categories** i will use dummy encoding (0/1). Here, each possible category would become a separate feature.
#
# What are the Ordered categories and Unordered categories features in our data set?
# - to programatically retrieve feasures based on there type i used Python code:
#  - **Unordered categories:**
#     <code>dictionary[pd.notna(dictionary["Encoding"])]["New Name"]</code>
#  - **Ordered categories:** <code>[students[students.columns.difference(dummies)] </code>

# %% [markdown]
# 1.filter the data dictionary to get only the nominal feature names (unordered categories) that needs to be dummied

# %%
unordered=dictionary[pd.notna(dictionary["Encoding"])]["New Name"]
dummies=pd.get_dummies(students[unordered],drop_first=True)

# %% [markdown]
# 2.Concatenate data frame of dummies with  ordered categories of original data fram .

# %%
students_dummies = pd.concat([students[students.columns.difference(unordered)], dummies], axis=1)

# %% [markdown]
# ### - How dependant variable **final_score** is correlated with independant variables?

# %%
students.corr()["final_score"]
# Out:
# age                     -0.125282
# mother_education         0.201472
# father_education         0.159796
# commute_time            -0.102627
# study_time               0.161629
# failures                -0.383145
# family_quality           0.054461
# free_time               -0.064890
# go_out                  -0.097877
# weekday_alcohol_usage   -0.129642
# weekend_alcohol_usage   -0.115740
# health                  -0.080079
# absences                -0.045671
# period1_score            0.809142
# period2_score            0.910743
# final_score              1.000000
# Name: final_score, dtype: float64

# %% [markdown]
# - I will select the most 10 correlated predictors with target variable

# %%
most_correlated = students_dummies.corr().abs()['final_score'].sort_values(ascending=False)
most_correlated = most_correlated[:12]

# %% [markdown]
# - Now that we have the most correlated variables names, we need to subset or data frame -**students_dummies**- so it only include the most correlated variables with the target variable:

# %%
students_dummies = students_dummies.loc[:, most_correlated.index]
students_dummies
# Out:
#       final_score  period2_score  period1_score  failures  \
# 0               6              6              5         0
# 1               6              5              5         0
# 2              10              8              7         3
# 3              15             14             15         0
# 4              10             10              6         0
# ...           ...            ...            ...       ...
# 1039           10             11             10         1
# 1040           16             15             15         0
# 1041            9             12             11         0
# 1042           10             10             10         0
# 1043           11             11             10         0
#
#       desire_higher_edu_yes  mother_education  course_por  study_time  \
# 0                         1                 4           0           2
# 1                         1                 1           0           2
# 2                         1                 1           0           2
# 3                         1                 4           0           3
# 4                         1                 3           0           2
# ...                     ...               ...         ...         ...
# 1039                      1                 2           1           3
# 1040                      1                 3           1           2
# 1041                      1                 1           1           2
# 1042                      1                 3           1           1
# 1043                      1                 3           1           1
#
#       father_education  weekday_alcohol_usage  school_MS  age
# 0                    4                      1          0   18
# 1                    1                      1          0   17
# 2                    1                      2          0   15
# 3                    2                      1          0   15
# 4                    3                      1          0   16
# ...                ...                    ...        ...  ...
# 1039                 3                      1          1   19
# 1040                 1                      1          1   18
# 1041                 1                      1          1   18
# 1042                 1                      3          1   17
# 1043                 2                      3          1   18
#
# [1044 rows x 12 columns]

# %% [markdown]
# - **Now that the data is prepared, it's time for modeling.**
#
# ---

# %% [markdown]
# # 3.Modeling Process

# %% [markdown]
#   - I will build two models:
#     - **1.linear aggregation:**
#         The model will predict the student’s final score
#     - **2.Logistic Regression:**
#         The model will predict whether the student is likely to pass the final exam or not.

# %% [markdown]
# ## 1.Linear Regression

# %% [markdown]
# **Step 1:** Import the required class.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,HuberRegressor,LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report

# %% [markdown]
# **Step 2:**  Create a feature matrix called "X" with selected independent variable, and series called "y" that has the **final_score** column

# %%
feature_cols = students_dummies.iloc[:,1:].columns
X = students_dummies[feature_cols]
y = students_dummies.final_score

# %% [markdown]
# **Step 3:** Instantiate the estimator

# %%
linreg = LinearRegression()

# %% [markdown]
# **Step 3:** Fit the estimator

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123)
linreg.fit(X_train, y_train)
ols_predicted = linreg.predict(X_test)

# %% [markdown]
# **Step 4:** Evaluating the model

# %%
ols_scores=get_scores(y_test,ols_predicted)
ols_scores
# Out:
# {'MSE': 1.729, 'MAE': 0.898, 'MedAE': 0.651, 'RMSE': 1.315, 'R2': 0.884}

# %% [markdown]
# Let's understand some of these metrics from the actual data that we have, so let's take for example **MSE** and **RMSE** and **R2**:

# %% [markdown]
# **Mean Square Error (MSE):**
# - as it sounds, we need to calculate:
#
#     1. Errors
#     2. Square of Errors
#     3. Mean of Square of Erros

# %% [markdown]
# **1.Errors:** simply are the difference between predicted values and actual values:

# %%
E=y_test-ols_predicted

# %% [markdown]
# **2.Square of Errors:** the square of difference between predicted values and actual values:

# %%
SE=E**2

# %% [markdown]
# **3.Mean of Square of Errors:** the average of squared difference between predicted values and actual values:

# %%
MSE=SE.sum() / SE.count()
MSE
# Out:
# 1.7289362819144267

# %% [markdown]
# **Root Mean Square Error (MSE):**
# - calculated by taking the root of MSE:

# %%
RMSE=_math.sqrt(MSE)
RMSE
# Out:
# 1.314890216677585

# %% [markdown]
# ---
# Now let us see how OLS result would are changed if we feed the imputed data frame and the dropped data frame that we created earlier :

# %%
imputed_students=students_dummies.copy()
dropped_students=students_dummies.copy()

# %% [markdown]
# **For imputed_students dataframe,** i will substitute zero values of **final_score** column by the average of all non-zero final scores:

# %%
imputed_value=np.mean(imputed_students[imputed_students["final_score"]!=0].final_score) # Get Avrage
imputed_students["final_score"].replace(to_replace = 0, value = imputed_value,inplace=True) #replace 0 with average

# %% [markdown]
# **For dropped_students dataframe,** i will drop all rows that have zero values on **final_score** column:

# %%
rowstodelete = dropped_students[ dropped_students['final_score'] == 0 ].index #Get indexs of rows to be deleted
dropped_students.drop(rowstodelete , inplace=True) # Delete these row indexes from dataFrame

# %%
X = imputed_students[feature_cols]
y = imputed_students.final_score
linreg = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123)
linreg.fit(X_train, y_train)
ols_predicted_imputed = linreg.predict(X_test)
ols_scores_imputed=get_scores(y_test,ols_predicted_imputed)

# %%
X = dropped_students[feature_cols]
y = dropped_students.final_score
linreg = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123)
linreg.fit(X_train, y_train)
ols_predicted_dropped = linreg.predict(X_test)
ols_scores_dropped=get_scores(y_test,ols_predicted_dropped)

# %%
print (" OLS - No changes                   " + str(ols_scores))
print (" OLS - Imputed zero values by mean  " + str(ols_scores_imputed))
print (" OLS - Dropped zero values          " + str(ols_scores_dropped))
# Out:
#  OLS - No changes                   {'MSE': 1.729, 'MAE': 0.898, 'MedAE': 0.651, 'RMSE': 1.315, 'R2': 0.884}
#  OLS - Imputed zero values by mean  {'MSE': 2.437, 'MAE': 1.101, 'MedAE': 0.751, 'RMSE': 1.561, 'R2': 0.738}
#  OLS - Dropped zero values          {'MSE': 0.7, 'MAE': 0.658, 'MedAE': 0.514, 'RMSE': 0.837, 'R2': 0.92}

# %% [markdown]
# ---
# ### Huber Regressor ###
# - As we know that the data contains many zero values in the final score column, we had assumed three scenarios regarding this point, and we saw how deleting these rows leads to a better and more efficient model.
#
# - But what if we keep the data the same without any change and build a rubost model that might efficiently deal with these outliers, let us examin HUBER regressor.

# %%
X = students_dummies[feature_cols]
y = students_dummies.final_score
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123)
huber = HuberRegressor()
huber.fit(X_train, y_train)
huber_predicted=huber.predict(X_test)
huber_scores=get_scores(y_test,huber_predicted)
#list(zip(y_test,z))
# Out:
# C:\Users\Adel\AppData\Local\Programs\Python\Python37-32\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %% [markdown]
# - Comparing OLS with HUBER :

# %%
prediction_scores=pd.DataFrame(huber_scores,index=["Huber"])
#predictions.append(pd.Series(ols_scores))
prediction_scores=pd.concat([prediction_scores,pd.DataFrame(ols_scores,index=["OLS"])])
prediction_scores=pd.concat([prediction_scores,pd.DataFrame(ols_scores_imputed,index=["OLS - Imputed data"])])
prediction_scores=pd.concat([prediction_scores,pd.DataFrame(ols_scores_dropped,index=["OLS - Droped data"])])
prediction_scores
# Out:
#                       MSE    MAE  MedAE   RMSE     R2
# Huber               1.699  0.823  0.603  1.303  0.886
# OLS                 1.729  0.898  0.651  1.315  0.884
# OLS - Imputed data  2.437  1.101  0.751  1.561  0.738
# OLS - Droped data   0.700  0.658  0.514  0.837  0.920

# %%
#pred=pd.concat([Predictions,Predictions2],axis=1)
#pred.head(50).plot()
predictions=pd.DataFrame(list(zip(y_test,huber_predicted)),columns=["Actual","Pred_Huber"])
predictions=pd.concat([predictions,pd.DataFrame(ols_predicted,columns=["Pred_OLS"])],axis=1)
predictions=pd.concat([predictions,pd.DataFrame(ols_predicted_imputed,columns=["Pred_OLS_Imputed"])],axis=1)
predictions=pd.concat([predictions,pd.DataFrame(ols_predicted_dropped,columns=["Pred_OLS_droped"])],axis=1)
predictions.sample(n=100)
# Out:
#      Actual  Pred_Huber   Pred_OLS  Pred_OLS_Imputed  Pred_OLS_droped
# 257      15   15.003965  14.813463         14.225167              NaN
# 222      16   15.365920  15.452660         14.414726        13.629358
# 64       13   13.012526  12.755638         13.256983         9.496579
# 123       9    8.947879   8.507889         10.073310        11.317574
# 163      13   13.436739  13.406787         13.305060        16.386874
# ..      ...         ...        ...               ...              ...
# 219      18   16.030316  15.999046         15.328323         7.709866
# 157      18   18.601305  18.943847         17.650148         7.314301
# 174      12   12.436459  12.219546         12.001160         6.948018
# 250       9    7.356537   6.914884          9.483327              NaN
# 223      11   11.149307  10.814165         12.741275         5.054388
#
# [100 rows x 5 columns]

# %% [markdown]
# - As we expected, the model works best if we remove those zeros from the data set.
# - If we can not remove the outliers for a logical reason, the HUBER regressor can be good choice perform slightly better than OLS.
#
#
# ---

# %% [markdown]
# ## 2.Logistic Regression

# %% [markdown]
# - Creating new columns to indicate if the student is pass the final exam or not assuming that pass_score=10 , i will use this column as a target in a classification model .

# %%
students_dummies['pass'] = students_dummies.apply(lambda row: row.final_score > pass_score , axis=1)

# %% [markdown]
# #### Let us check our target variable

# %%
sns.countplot(x="pass",data=students_dummies,palette="hls")

# %%
LogReg=LogisticRegression()
y=students_dummies["pass"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123)
LogReg.fit(X,y)
print("mean accuracy:" + str(round(LogReg.score(X,y),2)))
# Out:
# mean accuracy:0.92

# %%
Log_predicted = LogReg.predict(X_test)
print(classification_report(y_test,Log_predicted))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.93      0.92        98
#         True       0.96      0.95      0.95       163
#
#     accuracy                           0.94       261
#    macro avg       0.94      0.94      0.94       261
# weighted avg       0.94      0.94      0.94       261

# %% [markdown]
# - for all students who classified "PASS", 96 percent was correct
# - for all students who were actually "PASS", 96  percent was classified correctly

# %% [markdown]
# - Lets see the predicted classes, and hilight incorrect predictions:

# %%
LogPredections=pd.DataFrame(list(zip(y_test,Log_predicted)),columns=["Actual","Predicted"])
LogPredections.style.apply(lambda x: ["background: yellow" if v != x.iloc[0] else "" for v in x], axis = 1)
# Out:
# <style  type="text/css" >
#     #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow1_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow7_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow19_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow20_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow62_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow84_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow86_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow94_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow95_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow98_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow106_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow116_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow127_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow168_col1 {
#             background:  yellow;
#         }    #T_34222cb0_9293_11ea_a62b_4cbb5888d70erow232_col1 {
#             background:  yellow;
#         }</style><table id="T_34222cb0_9293_11ea_a62b_4cbb5888d70e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Actual</th>        <th class="col_heading level0 col1" >Predicted</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow0_col0" class="data row0 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow0_col1" class="data row0 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow1_col0" class="data row1 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow2_col0" class="data row2 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow2_col1" class="data row2 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow3_col0" class="data row3 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow3_col1" class="data row3 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow4_col0" class="data row4 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow4_col1" class="data row4 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow5_col0" class="data row5 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow5_col1" class="data row5 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow6_col0" class="data row6 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow6_col1" class="data row6 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow7_col0" class="data row7 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow8_col0" class="data row8 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow8_col1" class="data row8 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow9_col0" class="data row9 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow9_col1" class="data row9 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow10_col0" class="data row10 col0" >False</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow10_col1" class="data row10 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow11_col0" class="data row11 col0" >False</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow11_col1" class="data row11 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow12_col0" class="data row12 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow12_col1" class="data row12 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow13_col0" class="data row13 col0" >True</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow14_col0" class="data row14 col0" >False</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_34222cb0_9293_11ea_a62b_4cbb5888d70elevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow15_col0" class="data row15 col0" >False</td>
#                         <td id="T_34222cb0_9293_11ea_a62b_4cbb5888d70erow15_col1" class="data row15 col1" >False</td>
