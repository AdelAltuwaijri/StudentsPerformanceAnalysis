# %% [markdown]
# # Student Performans Analysis #
# ### This is the final project required for data science nanodegree by GA & Misk Academy ###
#
# ---

# %% [markdown]
# Dataset available at : https://archive.ics.uci.edu/ml/datasets/student+performance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("white")
import statsmodels.api as sm

from sklearn import metrics
from sklearn.metrics import classification_report

# %%
#Contents auto-fit
pd.set_option('display.max_colwidth', 0)
pd.set_option("display.max_columns",None)
pass_score=10

# %% [markdown]
# ## 1. Loading Dataset

# %%
# load data files into data frame objects

math=pd.read_csv("./data/student-mat.csv",delimiter=";")
por=pd.read_csv("./data/student-por.csv",delimiter=";")
math['course']="math"
por['course']="por"
dictionary=pd.read_excel("./data/dictionary.xlsx")
#merging data frams into one data fram
students=pd.concat([math,por],ignore_index = True)

# %% [markdown]
# #### - Data Dictionary :

# %%
dictionary
# Out:
#       Variable               New Name  \
# 0   school      school
# 1   sex         gender
# 2   age         age
# 3   address     address
# 4   famsize     family_size
# 5   Pstatus     parents_status
# 6   Medu        mother_education
# 7   Fedu        father_education
# 8   Mjob        mother_job
# 9   Fjob        father_job
# 10  reason      reason
# 11  guardian    guardian
# 12  traveltime  commute_time
# 13  studytime   study_time
# 14  failures    failures
# 15  schoolsup   school_support
# 16  famsup      family_support
# 17  paid        paid_classes
# 18  nursery     activities
# 19  activities  nursery
# 20  higher      desire_higher_edu
# 21  internet    internet
# 22  romantic    romantic
# 23  famrel      family_quality
# 24  freetime    free_time
# 25  goout       go_out
# 26  Dalc        weekday_alcohol_usage
# 27  Walc        weekend_alcohol_usage
# 28  health      health
# 29  absences    absences
# 30  G1          period1_score
# 31  G2          period2_score
# 32  G3          final_score
#
#                                                                                                                                       Description  \
# 0   student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# 1   student's sex (binary: 'F' - female or 'M' - male)
# 2   student's age (numeric: from 15 to 22)
# 3   student's home address type (binary: 'U' - urban or 'R' - rural)
# 4   family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 5   parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# 6   mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3-secondary education or 4 -higher education)
# 7   father's education (numeric: 0 - none, 1 - primary education (4th grade), 2(5th to 9th grade), 3-secondary education or 4-higher education)
# 8   mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 9   father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10  reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# 11  student's guardian (nominal: 'mother', 'father' or 'other')
# 12  home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 13  weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 14  number of past class failures (numeric: n if 1<=n<3, else 4)
# 15  extra educational support (binary: yes or no)
# 16  family educational support (binary: yes or no)
# 17  extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 18  attended nursery school (binary: yes or no)
# 19  extra-curricular activities (binary: yes or no)
# 20  wants to take higher education (binary: yes or no)
# 21  Internet access at home (binary: yes or no)
# 22  with a romantic relationship (binary: yes or no)
# 23  quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 24  free time after school (numeric: from 1 - very low to 5 - very high)
# 25  going out with friends (numeric: from 1 - very low to 5 - very high)
# 26  workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 27  weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28  current health status (numeric: from 1 - very bad to 5 - very good)
# 29  number of school absences (numeric: from 0 to 93)
# 30  first period grade (numeric: from 0 to 20)
# 31  second period grade (numeric: from 0 to 20)
# 32  final grade (numeric: from 0 to 20, output target)
#
#                                                            Encoding
# 0   {"MS":1,"GP":2}
# 1   {"M":1,"F":0}
# 2   NaN
# 3   {"U":1,"R":0}
# 4   {"GT3":1,"LE3":0}
# 5   {"T":1,"A":0}
# 6   NaN
# 7   NaN
# 8   {'services':1, 'at_home':2, 'teacher':3, 'health':4, 'other':5}
# 9   {'services':1, 'at_home':2, 'teacher':3, 'health':4, 'other':5}
# 10  {'course':1, 'home':2, 'reputation':3, 'other':4}
# 11  {'mother':1, 'father':2, 'other':3}
# 12  NaN
# 13  NaN
# 14  NaN
# 15  {"yes":1,"no":0}
# 16  {"yes":1,"no":0}
# 17  {"yes":1,"no":0}
# 18  {"yes":1,"no":0}
# 19  {"yes":1,"no":0}
# 20  {"yes":1,"no":0}
# 21  {"yes":1,"no":0}
# 22  {"yes":1,"no":0}
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
# 30  NaN
# 31  NaN
# 32  NaN

# %% [markdown]
# #### - Functions

# %%
# This function takes a column name as a parameter
# and returns a data frame with maximum and minimum value
# of a given column name associeted with a its row values
def min_max_value(col):
    top_index=students[col].idxmax()
    top_value=students["final_score"].max()
    d={top_value : students.loc[top_index] }
    top_obs=pd.DataFrame(data=d)
    
    bottom_index=students[col].idxmin()
    bottom_value=students["final_score"].min()
    d={bottom_value : students.loc[bottom_index]}
    bot_obs=pd.DataFrame(data=d)
    
    min_max_obs=pd.concat([top_obs,bot_obs],axis=1)
    
    return min_max_obs

# %%
# The plotting function below takes takes two arguments, the name of the column and the data associated with that column.
# I would call it repeatedly to plot some of variable distibutions. 
def distribution_plotter(column, data_set,x,y):
    data = data_set[column]
    sns.set(rc={"figure.figsize": (x, y)})
    sns.set(color_codes=True)
    sns.set(style="white", palette="muted")
    dist = sns.distplot(data, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    dist.set_title('Distribution of ' + column + '\n', fontsize=16)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# - Before any analysis step, i would prefer to change column labels to more descriptive names (as shown in dictionary):

# %%
students.columns = ['school','gender','age','address','family_size','parents_status','mother_education','father_education',
           'mother_job','father_job','reason','guardian','commute_time','study_time','failures','school_support',
          'family_support','paid_classes','activities','nursery','desire_higher_edu','internet','romantic','family_quality',
          'free_time','go_out','weekday_alcohol_usage','weekend_alcohol_usage','health','absences','period1_score','period2_score','final_score','course']

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p><b><span style="color:blue">&nbsp; How many rows and columns is there ? </span></b></p>

# %%
print("Rows: {}".format(students.shape[0]), "\nColumns: {}".format(students.shape[1]))
# Out:
# Rows: 1044
# Columns: 34

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; What is the data types of columns? </span></b></p>

# %%
students.dtypes.value_counts()
# Out:
# object    18
# int64     16
# dtype: int64

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; What is the meta data of the dataset? </span></b></p>

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   school                 1044 non-null   object
#  1   gender                 1044 non-null   object
#  2   age                    1044 non-null   int64
#  3   address                1044 non-null   object
#  4   family_size            1044 non-null   object
#  5   parents_status         1044 non-null   object
#  6   mother_education       1044 non-null   int64
#  7   father_education       1044 non-null   int64
#  8   mother_job             1044 non-null   object
#  9   father_job             1044 non-null   object
#  10  reason                 1044 non-null   object
#  11  guardian               1044 non-null   object
#  12  commute_time           1044 non-null   int64
#  13  study_time             1044 non-null   int64
#  14  failures               1044 non-null   int64
#  15  school_support         1044 non-null   object
#  16  family_support         1044 non-null   object
#  17  paid_classes           1044 non-null   object
#  18  activities             1044 non-null   object
#  19  nursery                1044 non-null   object
#  20  desire_higher_edu      1044 non-null   object
#  21  internet               1044 non-null   object
#  22  romantic               1044 non-null   object
#  23  family_quality         1044 non-null   int64
#  24  free_time              1044 non-null   int64
#  25  go_out                 1044 non-null   int64
#  26  weekday_alcohol_usage  1044 non-null   int64
#  27  weekend_alcohol_usage  1044 non-null   int64
#  28  health                 1044 non-null   int64
#  29  absences               1044 non-null   int64
#  30  period1_score          1044 non-null   int64
#  31  period2_score          1044 non-null   int64
#  32  final_score            1044 non-null   int64
#  33  course                 1044 non-null   object
# dtypes: int64(16), object(18)
# memory usage: 204.0+ KB

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Is there any missing values? </span></b></p>

# %%
students.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Is there any row duplications? </span></b></p>

# %%
students.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <b><span style="color:brown">&nbsp; No missing values, No duplications, Great ! </span></b>
#
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; List statistical summary of numerical data ? </span></b></p>

# %%
students.describe().T.style
# Out:
# <style  type="text/css" >
# </style><table id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70elevel0_row0" class="row_heading level0 row0" >age</th>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow0_col0" class="data row0 col0" >1044.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow0_col1" class="data row0 col1" >16.726054</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow0_col2" class="data row0 col2" >1.239975</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow0_col3" class="data row0 col3" >15.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow0_col4" class="data row0 col4" >16.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow0_col5" class="data row0 col5" >17.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow0_col6" class="data row0 col6" >18.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow0_col7" class="data row0 col7" >22.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70elevel0_row1" class="row_heading level0 row1" >mother_education</th>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow1_col0" class="data row1 col0" >1044.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow1_col1" class="data row1 col1" >2.603448</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow1_col2" class="data row1 col2" >1.124907</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow1_col4" class="data row1 col4" >2.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow1_col5" class="data row1 col5" >3.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow1_col6" class="data row1 col6" >4.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow1_col7" class="data row1 col7" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70elevel0_row2" class="row_heading level0 row2" >father_education</th>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow2_col0" class="data row2 col0" >1044.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow2_col1" class="data row2 col1" >2.387931</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow2_col2" class="data row2 col2" >1.099938</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow2_col4" class="data row2 col4" >1.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow2_col5" class="data row2 col5" >2.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow2_col6" class="data row2 col6" >3.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow2_col7" class="data row2 col7" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70elevel0_row3" class="row_heading level0 row3" >commute_time</th>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow3_col0" class="data row3 col0" >1044.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow3_col1" class="data row3 col1" >1.522989</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow3_col2" class="data row3 col2" >0.731727</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow3_col4" class="data row3 col4" >1.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow3_col5" class="data row3 col5" >1.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow3_col6" class="data row3 col6" >2.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow3_col7" class="data row3 col7" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70elevel0_row4" class="row_heading level0 row4" >study_time</th>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow4_col0" class="data row4 col0" >1044.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow4_col1" class="data row4 col1" >1.970307</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow4_col2" class="data row4 col2" >0.834353</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow4_col3" class="data row4 col3" >1.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow4_col5" class="data row4 col5" >2.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow4_col6" class="data row4 col6" >2.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow4_col7" class="data row4 col7" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70elevel0_row5" class="row_heading level0 row5" >failures</th>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow5_col0" class="data row5 col0" >1044.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow5_col1" class="data row5 col1" >0.264368</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow5_col2" class="data row5 col2" >0.656142</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow5_col3" class="data row5 col3" >0.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow5_col4" class="data row5 col4" >0.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow5_col5" class="data row5 col5" >0.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow5_col6" class="data row5 col6" >0.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow5_col7" class="data row5 col7" >3.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70elevel0_row6" class="row_heading level0 row6" >family_quality</th>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow6_col0" class="data row6 col0" >1044.000000</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow6_col1" class="data row6 col1" >3.935824</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow6_col2" class="data row6 col2" >0.933401</td>
#                         <td id="T_9e585f48_8d93_11ea_a2e4_4cbb5888d70erow6_col3" class="data row6 col3" >1.000000</td>
#                         <td i

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; List statistical summary of categorical/textual data ? </span></b></p>

# %%
students.describe(include=['object']).T.style
# Out:
# <style  type="text/css" >
# </style><table id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >unique</th>        <th class="col_heading level0 col2" >top</th>        <th class="col_heading level0 col3" >freq</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row0" class="row_heading level0 row0" >school</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow0_col0" class="data row0 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow0_col1" class="data row0 col1" >2</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow0_col2" class="data row0 col2" >GP</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow0_col3" class="data row0 col3" >772</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row1" class="row_heading level0 row1" >gender</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow1_col0" class="data row1 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow1_col1" class="data row1 col1" >2</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow1_col2" class="data row1 col2" >F</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow1_col3" class="data row1 col3" >591</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row2" class="row_heading level0 row2" >address</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow2_col0" class="data row2 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow2_col1" class="data row2 col1" >2</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow2_col2" class="data row2 col2" >U</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow2_col3" class="data row2 col3" >759</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row3" class="row_heading level0 row3" >family_size</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow3_col0" class="data row3 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow3_col1" class="data row3 col1" >2</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow3_col2" class="data row3 col2" >GT3</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow3_col3" class="data row3 col3" >738</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row4" class="row_heading level0 row4" >parents_status</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow4_col0" class="data row4 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow4_col1" class="data row4 col1" >2</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow4_col2" class="data row4 col2" >T</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow4_col3" class="data row4 col3" >923</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row5" class="row_heading level0 row5" >mother_job</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow5_col0" class="data row5 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow5_col1" class="data row5 col1" >5</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow5_col2" class="data row5 col2" >other</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow5_col3" class="data row5 col3" >399</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row6" class="row_heading level0 row6" >father_job</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow6_col0" class="data row6 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow6_col1" class="data row6 col1" >5</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow6_col2" class="data row6 col2" >other</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow6_col3" class="data row6 col3" >584</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row7" class="row_heading level0 row7" >reason</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow7_col0" class="data row7 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow7_col1" class="data row7 col1" >4</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow7_col2" class="data row7 col2" >course</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow7_col3" class="data row7 col3" >430</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row8" class="row_heading level0 row8" >guardian</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow8_col0" class="data row8 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow8_col1" class="data row8 col1" >3</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow8_col2" class="data row8 col2" >mother</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow8_col3" class="data row8 col3" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row9" class="row_heading level0 row9" >school_support</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow9_col0" class="data row9 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow9_col1" class="data row9 col1" >2</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow9_col2" class="data row9 col2" >no</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow9_col3" class="data row9 col3" >925</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row10" class="row_heading level0 row10" >family_support</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow10_col0" class="data row10 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow10_col1" class="data row10 col1" >2</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow10_col2" class="data row10 col2" >yes</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow10_col3" class="data row10 col3" >640</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row11" class="row_heading level0 row11" >paid_classes</th>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow11_col0" class="data row11 col0" >1044</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow11_col1" class="data row11 col1" >2</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow11_col2" class="data row11 col2" >no</td>
#                         <td id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70erow11_col3" class="data row11 col3" >824</td>
#             </tr>
#             <tr>
#                         <th id="T_9e618b0a_8d93_11ea_91b5_4cbb5888d70elevel0_row12" class="row_heading level0 row

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><div style="color:brown">
#
#    - It is noticeable that there are students who scored zero in the final exam!
#    - 50% of students have scored 11 -and lower- of 20.
#    - It seems there are outliers in absences variable. </div>
#
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; How many students got (Zero) score on final exam ? </span></b></p>

# %%
students[students['final_score'] == 0]["final_score"].count()
# Out:
# 53

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><div style="color:brown">
#
#    - For students who scored zero in the final exam, we do not have definite information as to whether these are real scores or are  parameter values for a reason, such as not taking the final exam.
#    - As a result I would prefer not dropping relative rows. </div>
#
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Statistically, descripe students who take 0 in final exam ? </span></b></p>

# %%
students[students['final_score'] == 0].describe()
# Out:
#              age  mother_education  father_education  commute_time  \
# count  53.000000  53.000000         53.000000         53.000000
# mean   17.283019  2.301887          2.113208          1.660377
# std    1.246184   1.066715          1.068075          0.758120
# min    15.000000  1.000000          1.000000          1.000000
# 25%    16.000000  1.000000          1.000000          1.000000
# 50%    18.000000  2.000000          2.000000          2.000000
# 75%    18.000000  3.000000          3.000000          2.000000
# max    19.000000  4.000000          4.000000          4.000000
#
#        study_time   failures  family_quality  free_time     go_out  \
# count  53.000000   53.000000  53.000000       53.000000  53.000000
# mean   1.830189    0.886792   3.849057        3.245283   3.169811
# std    0.848887    1.012620   1.098885        0.958879   1.410617
# min    1.000000    0.000000   1.000000        1.000000   1.000000
# 25%    1.000000    0.000000   3.000000        3.000000   2.000000
# 50%    2.000000    1.000000   4.000000        3.000000   3.000000
# 75%    2.000000    1.000000   5.000000        4.000000   4.000000
# max    4.000000    3.000000   5.000000        5.000000   5.000000
#
#        weekday_alcohol_usage  weekend_alcohol_usage     health  absences  \
# count  53.000000              53.000000              53.000000  53.0
# mean   1.490566               2.132075               3.660377   0.0
# std    0.799583               1.256334               1.300050   0.0
# min    1.000000               1.000000               1.000000   0.0
# 25%    1.000000               1.000000               3.000000   0.0
# 50%    1.000000               2.000000               4.000000   0.0
# 75%    2.000000               3.000000               5.000000   0.0
# max    4.000000               5.000000               5.000000   0.0
#
#        period1_score  period2_score  final_score
# count  53.000000      53.000000      53.0
# mean   7.396226       4.415094       0.0
# std    1.801064       3.707757       0.0
# min    4.000000       0.000000       0.0
# 25%    6.000000       0.000000       0.0
# 50%    7.000000       5.000000       0.0
# 75%    8.000000       8.000000       0.0
# max    12.000000      10.000000      0.0

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;Who is the top ten percent of students performing in the final exam?? </span></b></p>

# %%
Top_10_perc = students.sort_values(by="final_score",ascending=False).head(int(round((students["age"].count())) * .10))
Top_10_perc
# Out:
#     school gender  age address family_size parents_status  mother_education  \
# 47   GP     M      16   U       GT3         T              4
# 286  GP     F      18   U       GT3         T              2
# 374  MS     F      18   R       LE3         T              4
# 113  GP     M      15   U       LE3         T              4
# 110  GP     M      15   U       LE3         A              4
# ..   ..    ..      ..  ..       ...        ..             ..
# 69   GP     F      15   R       LE3         T              3
# 299  GP     M      18   U       LE3         T              4
# 596  GP     M      16   U       LE3         T              2
# 391  MS     M      17   U       LE3         T              3
# 59   GP     F      16   U       GT3         T              4
#
#      father_education mother_job father_job      reason guardian  \
# 47   3                 health     services   reputation  mother
# 286  2                 at_home    at_home    other       mother
# 374  4                 other      other      reputation  mother
# 113  2                 teacher    other      course      mother
# 110  4                 teacher    teacher    course      mother
# ..  ..                     ...        ...       ...         ...
# 69   1                 other      other      reputation  father
# 299  4                 teacher    teacher    home        mother
# 596  1                 other      other      course      mother
# 391  1                 services   services   course      mother
# 59   2                 services   other      course      mother
#
#      commute_time  study_time  failures school_support family_support  \
# 47   1             4           0         no             no
# 286  1             3           0         no             yes
# 374  2             3           0         no             no
# 113  1             1           0         no             no
# 110  1             1           0         no             no
# ..  ..            ..          ..         ..             ..
# 69   2             4           0         no             yes
# 299  1             1           0         no             yes
# 596  1             2           0         no             no
# 391  2             1           0         no             no
# 59   1             2           0         no             yes
#
#     paid_classes activities nursery desire_higher_edu internet romantic  \
# 47   no           yes        yes     yes               yes      no
# 286  yes          no         yes     yes               yes      no
# 374  no           no         yes     yes               yes      no
# 113  no           no         yes     yes               yes      no
# 110  no           yes        yes     yes               yes      no
# ..   ..           ...        ...     ...               ...      ..
# 69   no           no         no      yes               yes      no
# 299  yes          no         yes     yes               yes      yes
# 596  no           yes        yes     yes               yes      yes
# 391  no           no         no      yes               yes      no
# 59   no           no         yes     yes               yes      no
#
#      family_quality  free_time  go_out  weekday_alcohol_usage  \
# 47   4               2          2       1
# 286  4               3          3       1
# 374  5               4          4       1
# 113  3               5          2       1
# 110  5               5          3       1
# ..  ..              ..         ..      ..
# 69   4               4          2       2
# 299  1               4          2       2
# 596  4               2          3       1
# 391  2               4          5       3
# 59   4               2          3       1
#
#      weekend_alcohol_usage  health  absences  period1_score  period2_score  \
# 47   1                      2       4         19             19
# 286  2                      2       5         18             18
# 374  1                      1       0         19             18
# 113  1                      3       10        18             19
# 110  1                      4       6         18             19
# ..  ..                     ..      ..         ..             ..
# 69   3                      3       12        16             16
# 299  2                      1       5         16             15
# 596  2                      5       0         13             14
# 391  4                      2       3         14             16
# 59   1                      5       2         15             16
#
#      final_score course
# 47   20           math
# 286  19           math
# 374  19           math
# 113  19           math
# 110  19           math
# ..   ..            ...
# 69   16           math
# 299  16           math
# 596  16           por
# 391  16           math
# 59   16           math
#
# [104 rows x 34 columns]

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;What is the main statistical characteristics of top ten percent of students performing in the final exam?</span></b></p>

# %%
Top_10_perc.describe(include="all").T.style
# Out:
# <style  type="text/css" >
# </style><table id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >unique</th>        <th class="col_heading level0 col2" >top</th>        <th class="col_heading level0 col3" >freq</th>        <th class="col_heading level0 col4" >mean</th>        <th class="col_heading level0 col5" >std</th>        <th class="col_heading level0 col6" >min</th>        <th class="col_heading level0 col7" >25%</th>        <th class="col_heading level0 col8" >50%</th>        <th class="col_heading level0 col9" >75%</th>        <th class="col_heading level0 col10" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70elevel0_row0" class="row_heading level0 row0" >school</th>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col0" class="data row0 col0" >104</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col1" class="data row0 col1" >2</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col2" class="data row0 col2" >GP</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col3" class="data row0 col3" >83</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col4" class="data row0 col4" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col9" class="data row0 col9" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow0_col10" class="data row0 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70elevel0_row1" class="row_heading level0 row1" >gender</th>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col0" class="data row1 col0" >104</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col1" class="data row1 col1" >2</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col2" class="data row1 col2" >F</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col3" class="data row1 col3" >62</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col4" class="data row1 col4" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col6" class="data row1 col6" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col8" class="data row1 col8" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col9" class="data row1 col9" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow1_col10" class="data row1 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70elevel0_row2" class="row_heading level0 row2" >age</th>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col0" class="data row2 col0" >104.000000</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col4" class="data row2 col4" >16.634615</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col5" class="data row2 col5" >1.061760</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col6" class="data row2 col6" >15.000000</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col7" class="data row2 col7" >16.000000</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col8" class="data row2 col8" >17.000000</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col9" class="data row2 col9" >17.000000</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow2_col10" class="data row2 col10" >20.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70elevel0_row3" class="row_heading level0 row3" >address</th>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col0" class="data row3 col0" >104</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col1" class="data row3 col1" >2</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col2" class="data row3 col2" >U</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col3" class="data row3 col3" >82</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col4" class="data row3 col4" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col6" class="data row3 col6" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col7" class="data row3 col7" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col8" class="data row3 col8" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col9" class="data row3 col9" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow3_col10" class="data row3 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70elevel0_row4" class="row_heading level0 row4" >family_size</th>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col0" class="data row4 col0" >104</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col1" class="data row4 col1" >2</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col2" class="data row4 col2" >GT3</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col3" class="data row4 col3" >68</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col4" class="data row4 col4" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col6" class="data row4 col6" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col7" class="data row4 col7" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col8" class="data row4 col8" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col9" class="data row4 col9" >nan</td>
#                         <td id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70erow4_col10" class="data row4 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9e9a0a26_8d93_11ea_8bef_4cbb5888d70elevel0_row5" class="row_

# %% [markdown]
#
#  <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><div style="color:brown">
#
#    - Notes on the top 10 percent of students :
#  - More than 50 percent of students are female
#  - More than 85 percent of students live with their parents
#  - Almost 75 percent of students do not have emotional relationships
#  - All of students wants to take higher education
#  - Almost 99 percent of student did not get extra educational support </div>
#
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;Do males doing better than females in final exam?</span></b></p>

# %%
students.groupby('gender').final_score.mean()
# Out:
# gender
# F    11.448393
# M    11.203091
# Name: final_score, dtype: float64

# %% [markdown]
#  <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><div style="color:brown">
#
#    - Females scored bit hieghr than males In average . </div>
#
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Comparing students performance among two schools ,by gender:</span></b></p>

# %%
 pd.crosstab([students.gender],students.school,values=students["final_score"],aggfunc="mean",margins=True)
# Out:
# school         GP         MS        All
# gender
# F       11.683333  10.871345  11.448393
# M       11.573864  9.910891   11.203091
# All     11.633420  10.514706  11.341954

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><div style="color:brown">
#
#   - From above table we can see that GP students performed better than MS students. </div>
#
# ---

# %%
plt.size=(3,3)
students.hist(column='final_score', by='school',sharex=True, sharey=True);

# %% [markdown]
# ---

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;How students ages are distriputed ?</span></b></p>

# %%
distribution_plotter("age", students,5,2)

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; For each age, how many students? and what is the mean and median of there final score ?</span></b></p>

# %%
students.groupby(['age','gender']).final_score.agg(["count","mean","median"])
# Out:
#             count       mean  median
# age gender
# 15  F       95     11.021053  11.0
#     M       99     12.444444  12.0
# 16  F       159    11.779874  12.0
#     M       122    11.450820  11.5
# 17  F       171    12.070175  12.0
#     M       106    10.745283  10.0
# 18  F       127    11.125984  11.0
#     M       95     10.715789  11.0
# 19  F       33     8.939394   10.0
#     M       23     9.000000   10.0
# 20  F       5      12.400000  12.0
#     M       4      13.000000  12.5
# 21  F       1      12.000000  12.0
#     M       2      8.500000   8.5
# 22  M       2      6.500000   6.5

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp;Who is the best and lowest performing among students</span></b></p>

# %%
 min_max_value("final_score")
# Out:
#                                20           0
# school                 GP          GP
# gender                 M           M
# age                    16          18
# address                U           R
# family_size            GT3         GT3
# parents_status         T           T
# mother_education       4           2
# father_education       3           2
# mother_job             health      services
# father_job             services    other
# reason                 reputation  reputation
# guardian               mother      mother
# commute_time           1           1
# study_time             4           1
# failures               0           2
# school_support         no          no
# family_support         no          yes
# paid_classes           no          no
# activities             yes         yes
# nursery                yes         yes
# desire_higher_edu      yes         yes
# internet               yes         yes
# romantic               no          no
# family_quality         4           3
# free_time              2           3
# go_out                 2           3
# weekday_alcohol_usage  1           1
# weekend_alcohol_usage  1           2
# health                 2           4
# absences               4           0
# period1_score          19          7
# period2_score          19          4
# final_score            20          0
# course                 math        math

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; How final scores are disriputed ?</span></b></p>

# %%
distribution_plotter("final_score", students,5,2)

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; What is the relationship between period1_score and period2_score ?</span></b></p>

# %%
students.plot(kind="scatter",x="period1_score", y="period2_score")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# <img src="./data/QA.png" style="float:left; margin:0px; height: 30px">
# <p> <b><span style="color:blue">&nbsp; Is there a correlation among the columns in the dataframe using ‘Pearson’ method. ? </span></b></p>

# %%
students.corr(method ='pearson')
# Out:
#                             age  mother_education  father_education  \
# age                    1.000000 -0.130196         -0.138521
# mother_education      -0.130196  1.000000          0.642063
# father_education      -0.138521  0.642063          1.000000
# commute_time           0.049216 -0.238181         -0.196328
# study_time            -0.007870  0.090616          0.033458
# failures               0.282364 -0.187769         -0.191390
# family_quality         0.007162  0.015004          0.013066
# free_time              0.002645  0.001054          0.002142
# go_out                 0.118510  0.025614          0.030075
# weekday_alcohol_usage  0.133453  0.001515         -0.000165
# weekend_alcohol_usage  0.098291 -0.029331          0.019524
# health                -0.029129 -0.013254          0.034288
# absences               0.153196  0.059708          0.040829
# period1_score         -0.124121  0.226101          0.195898
# period2_score         -0.119475  0.224662          0.182634
# final_score           -0.125282  0.201472          0.159796
#
#                        commute_time  study_time  failures  family_quality  \
# age                    0.049216     -0.007870    0.282364  0.007162
# mother_education      -0.238181      0.090616   -0.187769  0.015004
# father_education      -0.196328      0.033458   -0.191390  0.013066
# commute_time           1.000000     -0.081328    0.087177 -0.012578
# study_time            -0.081328      1.000000   -0.152024  0.012324
# failures               0.087177     -0.152024    1.000000 -0.053676
# family_quality        -0.012578      0.012324   -0.053676  1.000000
# free_time             -0.007403     -0.094429    0.102679  0.136901
# go_out                 0.049740     -0.072941    0.074683  0.080619
# weekday_alcohol_usage  0.109423     -0.159665    0.116336 -0.076483
# weekend_alcohol_usage  0.084292     -0.229073    0.107432 -0.100663
# health                -0.029002     -0.063044    0.048311  0.104101
# absences              -0.022669     -0.075594    0.099998 -0.062171
# period1_score         -0.121053      0.211314   -0.374175  0.036947
# period2_score         -0.140163      0.183167   -0.377172  0.042054
# final_score           -0.102627      0.161629   -0.383145  0.054461
#
#                        free_time    go_out  weekday_alcohol_usage  \
# age                    0.002645   0.118510  0.133453
# mother_education       0.001054   0.025614  0.001515
# father_education       0.002142   0.030075 -0.000165
# commute_time          -0.007403   0.049740  0.109423
# study_time            -0.094429  -0.072941 -0.159665
# failures               0.102679   0.074683  0.116336
# family_quality         0.136901   0.080619 -0.076483
# free_time              1.000000   0.323556  0.144979
# go_out                 0.323556   1.000000  0.253135
# weekday_alcohol_usage  0.144979   0.253135  1.000000
# weekend_alcohol_usage  0.130377   0.399794  0.627814
# health                 0.081517  -0.013736  0.065515
# absences              -0.032079   0.056142  0.132867
# period1_score         -0.051985  -0.101163 -0.150943
# period2_score         -0.068952  -0.108411 -0.131576
# final_score           -0.064890  -0.097877 -0.129642
#
#                        weekend_alcohol_usage    health  absences  \
# age                    0.098291              -0.029129  0.153196
# mother_education      -0.029331              -0.013254  0.059708
# father_education       0.019524               0.034288  0.040829
# commute_time           0.084292              -0.029002 -0.022669
# study_time            -0.229073              -0.063044 -0.075594
# failures               0.107432               0.048311  0.099998
# family_quality        -0.100663               0.104101 -0.062171
# free_time              0.130377               0.081517 -0.032079
# go_out                 0.399794              -0.013736  0.056142
# weekday_alcohol_usage  0.627814               0.065515  0.132867
# weekend_alcohol_usage  1.000000               0.106669  0.139703
# health                 0.106669               1.000000 -0.027479
# absences               0.139703              -0.027479  1.000000
# period1_score         -0.142401              -0.060478 -0.092425
# period2_score         -0.128114              -0.088001 -0.089332
# final_score           -0.115740              -0.080079 -0.045671
#
#                        period1_score  period2_score  final_score
# age                   -0.124121      -0.119475      -0.125282
# mother_education       0.226101       0.224662       0.201472
# father_education       0.195898       0.182634       0.159796
# commute_time          -0.121053      -0.140163      -0.102627
# study_time             0.211314       0.183167       0.161629
# failures              -0.374175      -0.377172      -0.383145
# family_quality         0.036947       0.042054       0.054461
# free_time             -0.051985      -0.068952      -0.064890
# go_out                -0.101163      -0.108411      -0.097877
# weekday_alcohol_usage -0.150943      -0.131576      -0.129642
# weekend_alcohol_usage -0.142401      -0.128114      -0.115740
# health                -0.060478      -0.088001      -0.080079
# absences              -0.092425      -0.089332      -0.045671
# period1_score          1.000000       0.858739       0.809142
# period2_score          0.858739       1.000000       0.910743
# final_score            0.809142       0.910743       1.000000

# %% [markdown]
# <img src="./data/Notes.png" style="float:left; margin:0px; height: 20px">
# <p><b><div style="color:brown">
#
# - There is a positive linear relationship between *period1_score* and *period2_score*. </div>
#
# ---

# %% [markdown]
# ## Visualizing correlations:

# %%
sns.set_palette("coolwarm", 7)
sns.set(rc={"figure.figsize": (16, 8)})
sns.heatmap(students.corr(method ='pearson'), annot=True, linewidth=0.4, vmin=-1, vmax=1)
plt.yticks(rotation=0);

# %%
sns.pairplot(students[["final_score","age","mother_education","father_education","study_time","failures","absences"]])

# %% [markdown]
# ## 2.Features Engineering

# %% [markdown]
# - Because **period1_score** and **period2_score** are highly correlated, i will combine them into one variable taking thier average.

# %%
students["avg_Periods_score"]=(students["period1_score"]+students["period2_score"])/2
students.drop(columns=["period1_score","period2_score"],inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# - Creating new columns to indicate if the student is pass the final exam or not assuming that pass_score=10 , i will use this column as a target in a classification model .

# %%
students['pass'] = students.apply(lambda row: row.final_score > pass_score , axis=1)

# %% [markdown]
# ---

# %% [markdown]
# - Because **mother_education** and **father_education** are correlated, i will combine them into one variable taking thier average.

# %%
#students["mother_education"].corr(students["father_education"])
students["avg_parents_education"]=(students["mother_education"]+students["father_education"])/2
students.drop(columns=["mother_education","father_education"],inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# - Because **weekday_alcohol_usage** and **weekend_alcohol_usage** are highly correlated, i will combine them into one variable taking thier average.

# %%
#students.weekday_alcohol_usage.corr(students.weekend_alcohol_usage)
students["avg_alcohol_usage"]=(students["weekday_alcohol_usage"]+students["weekend_alcohol_usage"])/2
students.drop(columns=["weekday_alcohol_usage","weekend_alcohol_usage"],inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ### - How dependant variable **final_score** is correlated with independant variables?

# %%
students.corr()["final_score"]
# Out:
# age                     -0.125282
# commute_time            -0.102627
# study_time               0.161629
# failures                -0.383145
# family_quality           0.054461
# free_time               -0.064890
# go_out                  -0.097877
# health                  -0.080079
# absences                -0.045671
# final_score              1.000000
# avg_Periods_score        0.894479
# pass                     0.733140
# avg_parents_education    0.199607
# avg_alcohol_usage       -0.134244
# Name: final_score, dtype: float64

# %% [markdown]
# ---
#
# ### - How independant variables are correlated with each other ?

# %%
plt.figure(figsize=(27,12))
sns.heatmap(students.corr(),annot=True,cmap='YlGnBu')

# %% [markdown]
# ## 2.Features Engineering

# %% [markdown]
# For modeling purpose, i would convert all categorical values to numerical:

# %%
#Bivariant 
students["school"]=students["school"].map({"MS":1,"GP":2})
students["gender"]=students["gender"].map({"M":1,"F":0})
students["family_size"]=students["family_size"].map({"GT3":1,"LE3":0})
students["address"]=students["address"].map({"U":1,"R":0})
students["parents_status"]=students["parents_status"].map({"T":1,"A":0})
#YES/NO 
students["school_support"]=students["school_support"].map({"yes":1,"no":0})
students["family_support"]=students["family_support"].map({"yes":1,"no":0})
students["paid_classes"]=students["paid_classes"].map({"yes":1,"no":0})
students["activities"]=students["activities"].map({"yes":1,"no":0})
students["nursery"]=students["nursery"].map({"yes":1,"no":0})
students["desire_higher_edu"]=students["desire_higher_edu"].map({"yes":1,"no":0})
students["internet"]=students["internet"].map({"yes":1,"no":0})
students["romantic"]=students["romantic"].map({"yes":1,"no":0})
#Multivariant 
students['mother_job'] = students['mother_job'].map({'services':1, 'at_home':2, 'teacher':3, 'health':4, 'other':5})
students['father_job'] = students['father_job'].map({'services':1, 'at_home':2, 'teacher':3, 'health':4, 'other':5})
students['reason'] = students['reason'].map({'course':1, 'home':2, 'reputation':3, 'other':4})
students['guardian'] = students['guardian'].map({'mother':1, 'father':2, 'other':3})

# %%
students_copy = pd.get_dummies(students,drop_first=True)
students_copy
# Out:
#       school  gender  age  address  family_size  parents_status  mother_job  \
# 0     2       0       18   1        1            0               2
# 1     2       0       17   1        1            1               2
# 2     2       0       15   1        0            1               2
# 3     2       0       15   1        1            1               4
# 4     2       0       16   1        1            1               5
# ...  ..      ..       ..  ..       ..           ..              ..
# 1039  1       0       19   0        1            1               1
# 1040  1       0       18   1        0            1               3
# 1041  1       0       18   1        1            1               5
# 1042  1       1       17   1        0            1               1
# 1043  1       1       18   0        0            1               1
#
#       father_job  reason  guardian  commute_time  study_time  failures  \
# 0     3           1       1         2             2           0
# 1     5           1       2         1             2           0
# 2     5           4       1         1             2           3
# 3     1           2       1         1             3           0
# 4     5           2       2         1             2           0
# ...  ..          ..      ..        ..            ..          ..
# 1039  5           1       1         1             3           1
# 1040  1           1       1         1             2           0
# 1041  5           1       1         2             2           0
# 1042  1           1       1         2             1           0
# 1043  5           1       1         3             1           0
#
#       school_support  family_support  paid_classes  activities  nursery  \
# 0     1               0               0             0           1
# 1     0               1               0             0           0
# 2     1               0               1             0           1
# 3     0               1               1             1           1
# 4     0               1               1             0           1
# ...  ..              ..              ..            ..          ..
# 1039  0               0               0             1           0
# 1040  0               1               0             0           1
# 1041  0               0               0             1           1
# 1042  0               0               0             0           0
# 1043  0               0               0             0           0
#
#       desire_higher_edu  internet  romantic  family_quality  free_time  \
# 0     1                  0         0         4               3
# 1     1                  1         0         5               3
# 2     1                  1         0         4               3
# 3     1                  1         1         3               2
# 4     1                  0         0         4               3
# ...  ..                 ..        ..        ..              ..
# 1039  1                  1         0         5               4
# 1040  1                  1         0         4               3
# 1041  1                  0         0         1               1
# 1042  1                  1         0         2               4
# 1043  1                  1         0         4               4
#
#       go_out  health  absences  final_score  avg_Periods_score   pass  \
# 0     4       3       6         6            5.5                False
# 1     3       3       4         6            5.0                False
# 2     2       3       10        10           7.5                False
# 3     2       5       2         15           14.5               True
# 4     2       5       4         10           8.0                False
# ...  ..      ..      ..         ..           ...                  ...
# 1039  2       5       4         10           10.5               False
# 1040  4       1       4         16           15.0               True
# 1041  1       5       6         9            11.5               False
# 1042  5       2       6         10           10.0               False
# 1043  1       5       4         11           10.5               True
#
#       avg_parents_education  avg_alcohol_usage  course_por
# 0     4.0                    1.0                0
# 1     1.0                    1.0                0
# 2     1.0                    2.5                0
# 3     3.0                    1.0                0
# 4     3.0                    1.5                0
# ...   ...                    ...               ..
# 1039  2.5                    1.5                1
# 1040  2.0                    1.0                1
# 1041  1.0                    1.0                1
# 1042  2.0                    3.5                1
# 1043  2.5                    3.5                1
#
# [1044 rows x 32 columns]

# %%
most_correlated = students.corr().abs()['final_score'].sort_values(ascending=False)

# Maintain the top 8 most correlation features with Grade
most_correlated = most_correlated[:9]
most_correlated
# Out:
# final_score              1.000000
# avg_Periods_score        0.894479
# pass                     0.733140
# failures                 0.383145
# desire_higher_edu        0.236578
# avg_parents_education    0.199607
# study_time               0.161629
# avg_alcohol_usage        0.134244
# school                   0.127114
# Name: final_score, dtype: float64
